# %%
import pandas as pd
import numpy as np

# %%
# Read the csv file
df = pd.read_csv('country_vaccination_stats.csv')

# %%
df
# Out:
#       Unnamed: 0    country        date  daily_vaccinations  \
# 0              0  Argentina  12/29/2020              6483.0
# 1              1  Argentina  12/30/2020             15656.0
# 2              2  Argentina  12/31/2020             15656.0
# 3              3  Argentina    1/1/2021             11070.0
# 4              4  Argentina    1/2/2021              8776.0
# ...          ...        ...         ...                 ...
# 1497        1497      Wales   1/20/2021             11105.0
# 1498        1498      Wales   1/21/2021             12318.0
# 1499        1499      Wales   1/22/2021             15148.0
# 1500        1500      Wales   1/23/2021             17371.0
# 1501        1501      Wales   1/24/2021             17063.0
#
#                                  vaccines
# 0                               Sputnik V
# 1                               Sputnik V
# 2                               Sputnik V
# 3                               Sputnik V
# ...

# %%
top3 = df.groupby(['country'])['daily_vaccinations'].agg(Median_Vaccs='median').sort_values(by='Median_Vaccs',ascending=False).head(3)

# %%
top3 = pd.DataFrame(top3)

# %%
top3
# Out:
#                Median_Vaccs
# country
# United States      378253.0
# China              276786.0
# India              173922.0
